# %%
from config import yelp_api_key
import requests

# %% [markdown]
# ## Find Interested Business ID

# %%
# Define the endpoint URL
url = "https://api.yelp.com/v3/businesses/search"

# Define the headers
headers = {
    "Authorization": f"Bearer {yelp_api_key}"
}

# Define the parameters
params = {
    "location": "San Diego",
    "term": "h-mart"
}

# Make the API request
response = requests.get(url, headers=headers, params=params)

# Parse the response
data = response.json()

# Print the data
data
# Out:
# {'businesses': [{'id': 'Bow8ICyYaSdPxhiFJO7kSg',
#    'alias': 'h-mart-san-diego-balboa-san-diego',
#    'name': 'H Mart San Diego - Balboa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AJc7pi2pb7zK07lyFbIocQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-mart-san-diego-balboa-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 209,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.820731, 'longitude': -117.157479},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7725 Balboa Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7725 Balboa Ave', 'San Diego, CA 92111']},
#    'phone': '+18588369230',
#    'display_phone': '(858) 836-9230',
#    'distance': 3368.7965186831843},
#   {'id': '8ppQOm76k4AWTplDDyD9dw',
#    'alias': 'h-mart-san-diego-san-diego',
#    'name': 'H Mart - San Diego',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5Mv_3EuE6ANEe3WEHWEOHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-mart-san-diego-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 654,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.9186806570631,
#     'longitude': -117.122160039124},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9440 Mira Mesa Blvd.',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9440 Mira Mesa Blvd.', 'San Diego, CA 92126']},
#    'phone': '+18585770060',
#    'display_phone': '(858) 577-0060',
#    'distance': 14554.057999863438},
#   {'id': 'vcX99iOyg5mLymblXDxtUw',
#    'alias': 'zion-market-san-diego-3',
#    'name': 'Zion Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bObd3XfL1yvMAswwNkOIhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zion-market-san-diego-3?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 639,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.831369, 'longitude': -117.155172},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7655 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7655 Clairemont Mesa Blvd', 'San Diego, CA 92111']},
#    'phone': '+18582683300',
#    'display_phone': '(858) 268-3300',
#    'distance': 4537.844973778163},
#   {'id': '8P4JA6fxRDqKlprF-ReyIw',
#    'alias': 'mitsuwa-marketplace-san-diego',
#    'name': 'Mitsuwa Marketplace',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PW-W88WmY3ng4adVkuZI1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mitsuwa-marketplace-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 877,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8189196713073,
#     'longitude': -117.15080748608},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4240 Kearny Mesa Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4240 Kearny Mesa Rd', 'San Diego, CA 92111']},
#    'phone': '+18585696699',
#    'display_phone': '(858) 569-6699',
#    'distance': 3167.2354697238306},
#   {'id': 'sIHuq4o7IpZJgCn46VYGfA',
#    'alias': 'marukai-market-san-diego-san-diego-2',
#    'name': 'Marukai Market - San Diego',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NvhBMJqQNmiZnQEchjjvEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marukai-market-san-diego-san-diego-2?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 329,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8213, 'longitude': -117.14817},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8151 Balboa Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8151 Balboa Ave', 'San Diego, CA 92111']},
#    'phone': '+18583840248',
#    'display_phone': '(858) 384-0248',
#    'distance': 3482.6784319047047},
#   {'id': 'wkeqv2DzXAfCiHgkX6_mGA',
#    'alias': '99-ranch-market-san-diego',
#    'name': '99 Ranch Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HmKb0Km9gJVKB_sytqoP4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-ranch-market-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 762,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'markets', 'title': 'Fruits & Veggies'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.8333224123675,
#     'longitude': -117.160767883865},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7330 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7330 Clairemont Mesa Blvd', 'San Diego, CA 92111']},
#    'phone': '+18589748899',
#    'display_phone': '(858) 974-8899',
#    'distance': 4794.783663490195},
#   {'id': 'RTTyCCC3hXSm2FL6Jv-2sw',
#    'alias': 'jaws-express-san-diego',
#    'name': 'Jaws Express',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EahV__NcBna9VGU12iy7cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaws-express-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 33,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.820850343103174,
#     'longitude': -117.15754424361482},
#    'transactions': [],
#    'location': {'address1': '7725 Balboa Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7725 Balboa Ave', 'San Diego, CA 92111']},
#    'phone': '+18587167125',
#    'display_phone': '(858) 716-7125',
#    'distance': 3382.585701589207},
#   {'id': 'cyxKVVFQpC45x4Lmlf_OZQ',
#    'alias': 'bann-cuisine-san-diego',
#    'name': 'Bann Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4_i8pWp9AfqGFv6FBGGEKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bann-cuisine-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 165,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8216814, 'longitude': -117.1572084},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7725 Balboa Ave',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7725 Balboa Ave', 'Ste 3', 'San Diego, CA 92111']},
#    'phone': '+18588369253',
#    'display_phone': '(858) 836-9253',
#    'distance': 3471.8011220860103},
#   {'id': 'SxVIacd0mLyoAranYTeGKQ',
#    'alias': 'nijiya-market-san-diego-san-diego',
#    'name': 'Nijiya Market - San Diego',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y3UpHlKXFm_ARMrvVMBq5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nijiya-market-san-diego-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 385,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.81423, 'longitude': -117.15385},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3860 Convoy St',
#     'address2': 'Ste 121',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3860 Convoy St', 'Ste 121', 'San Diego, CA 92111']},
#    'phone': '+18582683821',
#    'display_phone': '(858) 268-3821',
#    'distance': 2635.884752954792},
#   {'id': 'G2FkEAevAy5W2xNYaS2zOw',
#    'alias': 'zzang-hot-dog-convoy-san-diego',
#    'name': 'ZZanG Hot Dog Convoy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W8RI8CFRzY0QAfey0wzlEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zzang-hot-dog-convoy-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 434,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.82094, 'longitude': -117.15823},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7725 Balboa Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7725 Balboa Ave', 'San Diego, CA 92111']},
#    'phone': '+18588369254',
#    'display_phone': '(858) 836-9254',
#    'distance': 3398.9660289191083},
#   {'id': '0ejyKrmjRH53ljlnxvJASQ',
#    'alias': '99-ranch-market-san-diego-2',
#    'name': '99 Ranch Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pmF1htu1UILpWC9l5FAGZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-ranch-market-san-diego-2?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 243,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'markets', 'title': 'Fruits & Veggies'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.82127, 'longitude': -117.17695},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5950 Balboa Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5950 Balboa Ave', 'San Diego, CA 92111']},
#    'phone': '+18583008899',
#    'display_phone': '(858) 300-8899',
#    'distance': 4062.73469385607},
#   {'id': 'FXJo0Pa0pAU0J6ldxKDWVw',
#    'alias': 'kyodong-noodle-san-diego',
#    'name': 'Kyodong Noodle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/32cGyGReKXr4LYxK2l3jpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyodong-noodle-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 28,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.820722, 'longitude': -117.157464},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7725 Balboa Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7725 Balboa Ave', 'San Diego, CA 92111']},
#    'phone': '+18588369255',
#    'display_phone': '(858) 836-9255',
#    'distance': 3398.9660289191083},
#   {'id': 'Ar9FS2eASCe6-jvyyZK0ig',
#    'alias': 'katzya-corn-dog-and-chicken-el-cajon-2',
#    'name': 'Katzya Corn Dog & Chicken',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TzNsvSdNZQnl7cVYU6Jig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzya-corn-dog-and-chicken-el-cajon-2?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 104,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.80524292752403,
#     'longitude': -116.96721943889358},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '415 Fletcher Pkwy',
#     'address2': 'Ste 681',
#     'address3': None,
#     'city': 'El Cajon',
#     'zip_code': '92020',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['415 Fletcher Pkwy', 'Ste 681', 'El Cajon, CA 92020']},
#    'phone': '+16194866762',
#    'display_phone': '(619) 486-6762',
#    'distance': 17541.986570954177},
#   {'id': 'un4fiS06vRKcRpKMcNmRog',
#    'alias': 'seafood-city-supermarket-mira-mesa-2',
#    'name': 'Seafood City Supermarket',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/azDT4ebWhdmC0Je1zwkxWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seafood-city-supermarket-mira-mesa-2?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 197,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 32.913682, 'longitude': -117.131647},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8922 Mira Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Mira Mesa',
#     'zip_code': '92126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8922 Mira Mesa Blvd', 'Mira Mesa, CA 92126']},
#    'phone': '+18585490200',
#    'display_phone': '(858) 549-0200',
#    'distance': 13848.983162138104},
#   {'id': 'TOE_5qNM3rp-W3OneJubnA',
#    'alias': 'thuan-phat-supermarket-san-diego',
#    'name': 'Thuan Phat Supermarket',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yEbUBHW7Y1AkbqJP9s0ZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thuan-phat-supermarket-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 180,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.7844657897949,
#     'longitude': -117.169784545898},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6935 Linda Vista Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6935 Linda Vista Rd', 'San Diego, CA 92111']},
#    'phone': '+18585650398',
#    'display_phone': '(858) 565-0398',
#    'distance': 1616.7135485933795},
#   {'id': 'QlSav9skFLLmtcG4rilOmg',
#    'alias': 'kyoto-gift-and-food-national-city',
#    'name': 'Kyoto Gift & Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xKvRurS7a1FTK-mPiWvhJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyoto-gift-and-food-national-city?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 111,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.66224, 'longitude': -117.08133},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1727 Sweetwater Rd',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'National City',
#     'zip_code': '91950',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1727 Sweetwater Rd',
#      'Ste 101',
#      'National City, CA 91950']},
#    'phone': '+16194773605',
#    'display_phone': '(619) 477-3605',
#    'distance': 15780.46937634283},
#   {'id': 'tyOafQHqsjYv6BTphxuWXA',
#    'alias': 'friends-house-korean-san-diego',
#    'name': "Friend's House Korean",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hSZcTCS8sHl2P4PnOyxZbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friends-house-korean-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 1239,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.825360107861535,
#     'longitude': -117.1547940288616},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4647 Convoy St',
#     'address2': 'Ste 101A',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4647 Convoy St', 'Ste 101A', 'San Diego, CA 92111']},
#    'phone': '+18582920499',
#    'display_phone': '(858) 292-0499',
#    'distance': 3869.116810692372},
#   {'id': '6Vj0EHnEsOWz6PnoTjsEOw',
#    'alias': 'oriental-food-market-escondido',
#    'name': 'Oriental Food Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tqLmlA07STIDdLoUoY5ObA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oriental-food-market-escondido?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 57,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'importedfood', 'title': 'Imported Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.1290696, 'longitude': -117.08704363497024},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '205 W Mission Ave',
#     'address2': 'Ste T',
#     'address3': '',
#     'city': 'Escondido',
#     'zip_code': '92025',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['205 W Mission Ave', 'Ste T', 'Escondido, CA 92025']},
#    'phone': '+17607459212',
#    'display_phone': '(760) 745-9212',
#    'distance': 38155.60231739929},
#   {'id': 'lZkDtieerG30fkrbcx6lew',
#    'alias': 'go-go-sushi-and-ramen-san-diego',
#    'name': 'Go Go Sushi & Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aO3dCpV7dLM57E7AnzwCLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/go-go-sushi-and-ramen-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 461,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.9183871, 'longitude': -117.1225405},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '9430 Mira Mesa Blvd',
#     'address2': 'Ste 5C',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9430 Mira Mesa Blvd',
#      'Ste 5C',
#      'San Diego, CA 92126']},
#    'phone': '+18585308600',
#    'display_phone': '(858) 530-8600',
#    'distance': 14514.855299469444},
#   {'id': 'YQ5Cm0hxQy19YI8A2wSM5w',
#    'alias': 'tofu-house-san-diego-2',
#    'name': 'Tofu House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DhTw-5uh3vQaa6MdAYdT3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tofu-house-san-diego-2?adjust_creative=RNM81PgQWfq6orp2BE0H8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'review_count': 656,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 32.9168177097635,
#     'longitude': -117.127392543657},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9089 Mira Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9089 Mira Mesa Blvd', 'San Diego, CA 92126']},
#    'phone': '+18588605296',
#    'display_phone': '(858) 860-5296',
#    'distance': 14257.83280024378}],
#  'total': 56,
#  'region': {'center': {'longitude': -117.15408325195312,
#    'latitude': 32.790569394537286}}}

# %%
# Give Business ID
business_id = "Bow8ICyYaSdPxhiFJO7kSg"

# Define the endpoint URL
url = f"https://api.yelp.com/v3/businesses/{business_id}/reviews"

# Define the headers
headers = {
    "Authorization": f"Bearer {yelp_api_key}"
}

# Define the parameters
params = {
}

# Make the API request
response = requests.get(url, headers=headers, params=params)

# Parse the response
data = response.json()

# Print the data
data
# Out:
# {'reviews': [{'id': 'rKyjn3y8AwsOc7WV5D5uVQ',
#    'url': 'https://www.yelp.com/biz/h-mart-san-diego-balboa-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&hrid=rKyjn3y8AwsOc7WV5D5uVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'text': 'Visiting from Florida - Never in my life have I seen such a market - almost totally catering to the Asian palate. Immense variety of fresh greens,...',
#    'rating': 5,
#    'time_created': '2023-08-21 19:11:23',
#    'user': {'id': '4OzCCA_FywfgKstdGDDb0A',
#     'profile_url': 'https://www.yelp.com/user_details?userid=4OzCCA_FywfgKstdGDDb0A',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/z1twOSlCMxbv5WI-3DkB_Q/o.jpg',
#     'name': 'Dr. Greg C.'}},
#   {'id': 'mjIHYNxDpC4gtMcdUYPtUg',
#    'url': 'https://www.yelp.com/biz/h-mart-san-diego-balboa-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&hrid=mjIHYNxDpC4gtMcdUYPtUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'text': 'Smaller food court, but workable. 4 food stands and a bakery inside. The Jaws Express we came to check out is located inside. \n\nThe banchans and ready made...',
#    'rating': 3,
#    'time_created': '2023-08-20 12:56:12',
#    'user': {'id': 'reOsjVoPYkAQyVVau2crFg',
#     'profile_url': 'https://www.yelp.com/user_details?userid=reOsjVoPYkAQyVVau2crFg',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/b6DY0c78LfqoJCG4VH5DQA/o.jpg',
#     'name': 'Nicole E.'}},
#   {'id': 'DU0a4s5DU-XcygfCA7Pocg',
#    'url': 'https://www.yelp.com/biz/h-mart-san-diego-balboa-san-diego?adjust_creative=RNM81PgQWfq6orp2BE0H8g&hrid=DU0a4s5DU-XcygfCA7Pocg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=RNM81PgQWfq6orp2BE0H8g',
#    'text': 'nice Asian market. focused on Korean (and to a lesser extent Japanese) groceries.\n\nstopped by because 99 Ranch Market which is around the corner and down...',
#    'rating': 4,
#    'time_created': '2023-07-19 03:03:29',
#    'user': {'id': 'sCiCkK_7CKNwzwo9c0PpKg',
#     'profile_url': 'https://www.yelp.com/user_details?userid=sCiCkK_7CKNwzwo9c0PpKg',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/QzGGBqN0wb5Qzu_GOcOtJA/o.jpg',
#     'name': 'Scott T.'}}],
#  'total': 209,
#  'possible_languages': ['en', 'de']}
