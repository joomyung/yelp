# %%
import pandas as pd

# read json of yelp_academic_dataset_business.json
df_business = pd.read_json('data/yelp_academic_dataset_business.json', lines=True)

# %%
'hmart' in df_business['name'].unique()
# Out:
# False

# %%
# store hmart business id
substrings = ['h-mart', 'hmart', 'h mart']
df_business[df_business['name'].str.lower().apply(lambda x: any(x.startswith(substr) for substr in substrings))]
# Out:
#                    business_id                   name  \
# 43575   HIAJ2mnlm_pP38_8GbgQ5g                  Hmart
# 53706   1UKBAgYxI9Qax3AA4ULw_w  H Mart - Philadelphia
# 102234  -wlmZ-b35UJ-GY-59NDxyw   H Mart - Elkins Park
# 111313  GNYNs8pu3J-GaSKLQueQSg   H Mart - Upper Darby
# 112256  iXMuh6475dWdvHNIaFs3Xw                 H-Mart
# 133223  t7lXDRAytv_pq5FLWSxtaQ   H Mart - Cherry Hill
#
#                               address          city state postal_code  \
# 43575   1138 Bristol Oxford Valley Rd     Levittown    PA       19057
# 53706    6201 North Front St, Ste 124  Philadelphia    PA       19120
# 102234              7320 Old York Rd.   Elkins Park    PA       19027
# 111313              7050 Terminal Sq.   Upper Darby    PA       19082
# 112256    570 - 3803 Calgary Trail NW      Edmonton    AB     T6J 5M8
# 133223              1720 Rt. 70 East.   Cherry Hill    NJ       08003
#
#          latitude   longitude  stars  review_count  is_open  \
# ...

# %%
hmart_ids = df_business[df_business['name'].str.lower().apply(lambda x: any(x.startswith(substr) for substr in substrings))]['business_id'].values
hmart_ids
# Out:
# array(['HIAJ2mnlm_pP38_8GbgQ5g', '1UKBAgYxI9Qax3AA4ULw_w',
#        '-wlmZ-b35UJ-GY-59NDxyw', 'GNYNs8pu3J-GaSKLQueQSg',
#        'iXMuh6475dWdvHNIaFs3Xw', 't7lXDRAytv_pq5FLWSxtaQ'], dtype=object)

# %%
# partially read json of yelp_academic_dataset_review.json

import json
from itertools import islice

filename = "data/yelp_academic_dataset_review.json"
with(open(filename)) as f:
    objects = (json.loads(line) for line in f)
    objects = islice(objects, 200)
    rows = list(objects)

# Convert to pandas DataFrame
df_review = pd.DataFrame(rows)

df_review
# Out:
#                   review_id                 user_id             business_id  \
# 0    KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1    BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2    saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3    AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4    Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ..                      ...                     ...                     ...
# 195  c9uUji8cUjVqkMisIfHjyg  zMeM0HTnNfjBffhgm-3EBA  dBCNUSbz5-8nQNrxWo5deg
# 196  ZNZMWPfPdbbM7dhZlIpoFA  zq2nd0H1dVzi3bta4Zepuw  JvawJ9bSr22xn4R9oLvl_w
# 197  IJCYT9dRjuBvY-BJufFnNg  hWDybu_KvYLSdEFzGrniTw  roc-xyyzN5b_nImb0NdRLQ
# 198  clKHv1f5cIsaJVJPdKKHZg  f0fqCwb_QAJUPm-K95Mk2g  NdqATFd0JsFzEOD8Z8pa5w
# 199  cOcKS8BQ7yjOJPatqK2OOQ  Lc5U0qetusunJZ0NgNO_Iw  Y2rYM2crYfTC25y6iquPgw
#
#      stars  useful  funny  cool  \
# ...
